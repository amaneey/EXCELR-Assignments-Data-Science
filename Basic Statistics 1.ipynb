# %% [markdown]
# Q7

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
from scipy import stats

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7a4946b5-44e6-45d8-b316-99786c4b07b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a4946b5-44e6-45d8-b316-99786c4b07b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Q7.csv")

# %%
df.max()
# Out:
# Unnamed: 0    Volvo 142E
# Points              4.93
# Score              5.424
# Weigh               22.9
# dtype: object

# %%
df.min()
# Out:
# Unnamed: 0    AMC Javelin
# Points               2.76
# Score               1.513
# Weigh                14.5
# dtype: object

# %%
df.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %%
df.mean()
# Out:
# <ipython-input-7-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-8-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-9-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %% [markdown]
# Q9

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-62be5147-1ef4-4288-b400-b30e3a973017" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62be5147-1ef4-4288-b400-b30e3a973017">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Q9_a.csv')

# %%
df.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0129f8a6-5197-4c19-a0c8-dedb0a9e4ad6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0129f8a6-5197-4c19-a0c8-dedb0a9e4ad6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Q9_b.csv')

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
df.kurt()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %% [markdown]
# Q 11

# %%
ci=stats.norm.interval(0.94,200,30)
ci
# Out:
# (143.57619175546247, 256.42380824453755)

# %%
ci=stats.norm.interval(0.96,200,30)
ci
# Out:
# (138.38753268104531, 261.61246731895466)

# %%
ci=stats.norm.interval(0.98,200,30)
ci
# Out:
# (130.2095637787748, 269.7904362212252)

# %% [markdown]
# Q 20

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ca9f2b90-a5d8-41de-baa1-f05d3f70281c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca9f2b90-a5d8-41de-baa1-f05d3f70281c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Cars.csv")

# %%
print('mean:',round(df['MPG'].mean(),1))
# Out:
# mean: 34.4

# %%
print('std:',round(df['MPG'].std(),1))
# Out:
# std: 9.1

# %%
from scipy import stats
1-stats.norm.cdf(38,34.4,9.1)
# Out:
# 0.34619844694628543

# %%
from scipy import stats
stats.norm.cdf(40,34.4,9.1)
# Out:
# 0.7308496254906386

# %%
from scipy import stats
(stats.norm.cdf(50,34.4,9.1))-(stats.norm.cdf(20,34.4,9.1))
# Out:
# 0.8999847305059647

# %%
import matplotlib.pyplot as plt
import seaborn as sn
sn.distplot(df.MPG)
# Out:
# <ipython-input-32-ab8e8223e115>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df.MPG)
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-234a4c5e-4ac3-4da7-a153-f2bc9625652e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-234a4c5e-4ac3-4da7-a153-f2bc9625652e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("WC_AT.csv")

# %%
sns.distplot(df)
# Out:
# <ipython-input-35-527cbf673b18>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)
# <Axes: ylabel='Density'>

# %% [markdown]
# Q 22

# %%
stats.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
stats.norm.ppf(0.97)
# Out:
# 1.8807936081512509

# %%
stats.norm.ppf(0.8)
# Out:
# 0.8416212335729143

# %% [markdown]
# Q 23

# %%
stats.t.ppf(0.975,df=24)
# Out:
# 2.0638985616280205

# %%
stats.t.ppf(0.97,23)
# Out:
# 1.9782491769088995

# %%
stats.t.ppf(0.995,df=23)
# Out:
# 2.8073356837675227

# %% [markdown]
# Q 24

# %%
stats.norm.cdf(-0.4714)
# Out:
# 0.31867755799243214
